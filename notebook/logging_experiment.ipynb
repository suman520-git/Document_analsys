# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import logging
import os
from datetime import datetime

# %%
os.getcwd()
# Out:
# 'd:\\document_portal\\notebook'

# %%
logs_dir=os.path.join(os.getcwd(),"logs")
os.makedirs(logs_dir, exist_ok=True)

# %%
LOG_FILE = f"{datetime.now().strftime('%m_%d_%Y_%H_%M_%S')}.log"

# %%
#this is a log file(name of the log file would current data and time)
LOG_FILE
# Out:
# '10_25_2025_21_23_51.log'

# %%
#today
# with today's date log file will be creted

#tomorrow
# with tomorrow's date log file will be created

# %%
LOG_FILE_PATH=os.path.join(logs_dir, LOG_FILE)

# %%
LOG_FILE_PATH
# Out:
# 'd:\\document_portal\\notebook\\logs\\10_25_2025_21_23_51.log'

# %%
logging.basicConfig(
    filename=LOG_FILE_PATH,
    format="[ %(asctime)s ] %(levelname)s %(name)s (line:%(lineno)d) - %(message)s",
    level=logging.INFO,
)

# %%
logger=logging.getLogger("DocumentPortal")
logger
# Out:
# <Logger DocumentPortal (INFO)>

# %%
logger.info("This is an info message")

# %%
logger
# Out:
# <Logger DocumentPortal (INFO)>

# %%
import structlog
log=structlog.get_logger()

# %%
log.info("User uploaded a file", user_id=123, filename="report.pdf")
# Out:
# 2025-10-25 21:31:47 [info     ] User uploaded a file           filename=report.pdf user_id=123

# %%
log.error("Failed to process PDF", error="File not found", user_id=123)
# Out:
# 2025-10-25 21:32:12 [error    ] Failed to process PDF          error='File not found' user_id=123

# %%
class MyClass:
    def __init__(self, name):
        self.name = name
    
    def __str__(self):
        return f"MyClass object cccwith name: {self.name}"
    
    def __repr__(self):
        return f"MyClass object bbbwith name: {self.name}"

# %%
obj=MyClass("suman")

# %%
obj
# Out:
# MyClass object bbbwith name: suman

# %%
print(obj)
# Out:
# MyClass object cccwith name: suman
